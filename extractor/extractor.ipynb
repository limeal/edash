# %% [markdown]
# # Epitech modules information extractor
#
# Cmd: /Applications/Arc.app/Contents/MacOS/Arc --remote-debugging-port=9222
# I have used playwright for that, it's a web driver that allow reading page content directly

# %%
import csv
import re
from playwright.async_api import async_playwright

# %% [markdown]
# ## Starting playwrigh in CDP mode
#
# We use cdp mode because we need to have a browser that's can bypass the epitech new verification guard. CDP allow to use the devtools in chromium browser into normal window, so that allow to directly read from the user view and bypass the check.

# %%
playwright = await async_playwright().start()
browser = await playwright.chromium.connect_over_cdp("http://localhost:9222")
default_context = browser.contexts[0]
pages = default_context.pages

base_module_url = "https://intra.epitech.eu/module"
epitechPage = next((page for page in pages if page.url.startswith(base_module_url)), None)

if epitechPage is None:
    print("Can't find epitech page")
    exit(1)

# %% [markdown]
# ## Extract the modules list from the tab

# %%
base_node = epitechPage.locator('//*[@id="sidebar"]/form/div[3]/dl')

#semesters = await base_node.locator('//dt/span/a').click()
moduleLocator = base_node.locator('//dd/dl/dt/a[2]')
count = await moduleLocator.count()

# %% [markdown]
# ## Creating a module class that will store all the value extracted

# %%
class Module:
    
    def __init__(
        self,
        title,
        description,
        code,
        instance,
        credits,
        skills,
        startDate,
        endDate,
        endRegistrationDate,
        project,
        activities,
        appointements,
        registered,
    ):
        # Merge location of activities and appointements
        locations = list(map(lambda activity: activity['location'], activities))
        locations += list(map(lambda appointement: appointement['location'], appointements))
        
        self.title = title
        self.description = description
        self.code = code
        self.instance = instance
        self.credits = credits
        self.skills = skills
        self.startDate = startDate
        self.endDate = endDate
        self.endRegistrationDate = endRegistrationDate
        self.isPresential = any(location.find('Visio') == -1 for location in locations)
        self.project_name = 'N/A' if project is None else project['name']
        self.project_link = 'N/A' if project is None else project['link']
        self.project_start_date = 'N/A' if project is None else project['start_date']
        self.project_end_date = 'N/A' if project is None else project['end_date']
        self.activities = list(map(lambda activity: activity['name'], activities))
        self.appointements = list(map(lambda appointement: appointement['name'], appointements))
        self.locations = locations
        self.registered = registered

    def __str__(self):
        return f"{self.title} ({self.code})"

    def __repr__(self):
        return self.__str__()
    
    def get_url(self):
        return f"{base_module_url}/2024/{self.code}/{self.instance}"

# %% [markdown]
# ## The functions that will extract the content

# %%
async def extract_appointements():
    activities = epitechPage.locator('//*[@id="module"]/div[3]/div/ul/li[contains(@class, "rdv")]')
    if activities is None:
        return []
    
    activitiesCount = await activities.count()
    appointements = []
    for i in range(activitiesCount):
        activity = activities.nth(i)
        
        activityTitle = await activity.locator(f'//div[1]/h2/span/a').inner_text()
        try:
            activityLocation = await activity.locator(f'//div[2]/div[2]/div/div[2]/div/div[3]/span[2]').inner_text(timeout=1000)
        except:
            activityLocation = None
            
        appointements.append({
            'name': activityTitle,
            'location': 'N/A' if activityLocation is None else activityLocation
        })
        
    return appointements

async def extract_activities():
    activities = epitechPage.locator('//*[@id="module"]/div[3]/div/ul/li[contains(@class, "tp")]')
    if activities is None:
        return []
    
    activitiesCount = await activities.count()
    
    activitiesResult = []
    for i in range(activitiesCount):
        activity = activities.nth(i)
        
        activityTitle = await activity.locator(f'//div[1]/h2/span/a').inner_text()
        try:
            activityLocation = await activity.locator(f'//div[2]/div[2]/div/div[2]/div/div[3]/span[2]').inner_text(timeout=1000)
        except:
            activityLocation = None
            
        activitiesResult.append({
            'name': activityTitle,
            'location': 'N/A' if activityLocation is None else activityLocation
        })
        
    return activitiesResult

async def extract_project(code, instance):
    projects = epitechPage.locator('//*[@id="module"]/div[3]/div/ul/li[contains(@class, "proj")]')
    if projects is None:
        return None
    projectsCount = await projects.count()
    if projectsCount == 0:
        return None
        
    project = projects.nth(0)
    projectTitle = await project.locator(f'//div[1]/h2/span/a').inner_text()
    try:
        projectStartDate = await project.locator(f'//div[2]/div[1]/div[1]/div[1]/span[2]').inner_text(timeout=1000)
    except:
        projectStartDate = None
        
    try:
        projectEndDate = await project.locator(f'//div[2]/div[1]/div[1]/div[2]/span[2]').inner_text(timeout=1000)
    except:
        projectEndDate = None
        
    try:
        projectLink = await project.locator(f'//div[2]/div[1]/div[2]/div[2]/div[1]/div/ul/li[1]/a').get_attribute(name='href', timeout=1000)
        projectLink = f'{base_module_url}/2024/{code}/{instance}/{projectLink}'
    except:
        projectLink = None
        
    return {
        'name': projectTitle,
        'link': projectLink,
        'start_date': projectStartDate,
        'end_date': projectEndDate
    }
    
async def get_students():
    registered_btn = epitechPage.locator('//*[@id="module"]/div[1]/div[2]/a[1]')
    if registered_btn is None:
        return []
    
    try:
        await registered_btn.click(timeout=1000)
        # Wait for the page to load
        await epitechPage.wait_for_load_state('load', timeout=2000)
        
        studentsList = epitechPage.locator('//*[@id="grid-note"]/div[2]/div/table/tbody/tr')
        count = await studentsList.count()
        
        students = []
        for i in range(count):
            student = studentsList.nth(i)
            studentName = await student.locator(f'//td[1]').inner_text()
            students.append(studentName)
        
        return students
    except:
        return []
    
    
async def extract_module_data():
    metadata = epitechPage.locator('//*[@id="module"]/div[1]/div[2]/div[3]')

    title = await metadata.locator('//h1').inner_text()
    
    codeModule = await metadata.locator('//div[1]/span').inner_text()
    codeModule = codeModule.lstrip('(').rstrip(')')

    codeInstance = await metadata.locator('//div[2]/span').inner_text()
    codeInstance = codeInstance.lstrip('(').rstrip(')')

    creditsNumber = await metadata.locator('//div[3]/span').inner_text()
    creditsNumber = creditsNumber.lstrip('(').split(' ')[0]

    timeline = epitechPage.locator('//*[@id="timeline"]/span/span')
    description = await epitechPage.locator('//*[@id="module"]/div[2]/div[2]/div[1]/div').inner_text(timeout=1000)

    skills = await epitechPage.locator('//*[@id="module"]/div[2]/div[2]/div[2]/div').inner_text(timeout=1000)
    skills = [re.sub(r'[^A-Za-z ]+', '', skill.strip()) for skill in skills.split('\n') if skill != '']

    startModuleDate = await timeline.locator('span.date_start.bulle').inner_text(timeout=1000)
    endModuleDate = await timeline.locator('span.date_end.bulle').inner_text(timeout=1000)
    endRegistration = await timeline.locator('span.wrapper-timeleft > span.end_reg > span').inner_text(timeout=1000)
    
    print(f"Extracting data for {title} ({codeModule})")
    
    appointements = await extract_appointements()
    print(f"Appointements: {appointements}")
    activities = await extract_activities()
    print(f"Activities: {activities}")
    project = await extract_project(codeModule, codeInstance)
    print(f"Project: {project}")
    registered = await get_students()
    print(f"Registered: {registered}")
    return Module(
        title,
        description,
        codeModule,
        codeInstance,
        creditsNumber,
        skills,
        startModuleDate.split(', ')[0],
        endModuleDate.split(', ')[0],
        endRegistration.split(', ')[0],
        project,
        activities,
        appointements,
        registered
    )

# %% [markdown]
# ## Launch the process on each module that we have found, so click on the page collect data needed and go to the next

# %%
modules = []

for i in range(count):
    await moduleLocator.nth(i).click()
    modules.append(await extract_module_data())
# Out:
# Extracting data for G9 - Certification Assessment (G-RCP-900)
# Appointements: [{'name': "Bloc 7 - Piloter un projet de conception et développment d'une solution logicielle", 'location': 'N/A'}, {'name': "Bloc 6 - Piloter la mise en production d'un projet de développement logiciel", 'location': 'N/A'}, {'name': "Bloc 5 - Définir et piloter la politique d'assurance qualité d'un projet de développement logiciel", 'location': 'N/A'}, {'name': 'Bloc 4 - Créer une architecture logicielle pour des applications web - AREA', 'location': 'N/A'}, {'name': 'Bloc 3 - Créer une architecture logicielle pour des applications dites "lourdes" - GLaDOS', 'location': 'N/A'}, {'name': 'Bloc 3 - Créer une architecture logicielle pour des applications dites "lourdes" - R-Type', 'location': 'N/A'}, {'name': 'Bloc 2 - Concevoir une architecture logicielle - R-Type', 'location': 'N/A'}, {'name': 'Bloc 2 - Concevoir une architecture logicielle - AREA', 'location': 'N/A'}, {'name': 'Bloc 2 - Concevoir une architecture logicielle - GLaDOS', 'location': '\n\t\t\t\t\tCassandra\t\t\t\t'}, {'name': 'Bloc 1 - Cadrer un projet de conception et développement logiciel', 'location': 'N/A'}]
# Activities: []
# Project: {'name': "Bloc 7 - Piloter un projet de conception et développment d'une solution logicielle", 'link': 'https://intra.epitech.eu/module/2024/G-RCP-900/PAR-9-1/acti-657933/project/#!/group', 'start_date': '03/02/2025, 00h00', 'end_date': '16/02/2025, 00h00'}
# Registered: ['abdelkarim.bengrine@epitech.eu', 'adria.marata-fernandez@epitech.eu', 'adrien.fort@epitech.eu', 'alex1.prevot@epitech.eu', 'alexandre.chetrit@epitech.eu', 'alexandre.grare@epitech.eu', 'alexis.cheron@epitech.eu', 'alwyn.mattapullut@epitech.eu', 'amoz.pay@epitech.eu', 'anthony.vienne@epitech.eu', 'antoine.blaise@epitech.eu', 'antoine.descamps@epitech.eu', 'antoine.gavira-bottari@epitech.eu', 'antoine.podvin@epitech.eu', 'antoine.van-gorp@epitech.eu', 'arent.dollapaj@epitech.eu', 'arnaud.ho-chouck-foune@epitech.eu', 'axel.boqueho@epitech.eu', 'baptiste.barbotin@epitech.eu', 'bastien.boymond@epitech.eu', 'bastien.cantet@epitech.eu', 'bastien2.schektman@epitech.eu', 'ciro.autiero@epitech.eu', 'clement.fernandes@epitech.eu', 'corentin.hervaud@epitech.eu', 'corentin.pilard@epitech.eu', 'corentin.vidal@epitech.eu', 'cyprien.piron@epitech.eu', 'david.gozlan
@epitech.eu', 'sandati.yahaya@epitech.eu', 'serguei.leonov@epitech.eu', 'siouly.nguy@epitech.eu', 'stepan.smirnov@epitech.eu', 'theo.abitbol@epitech.eu', 'theo.de-boysson@epitech.eu', 'theo.millasseau@epitech.eu', 'theo.regheasse@epitech.eu', 'theo.tarallo@epitech.eu', 'thibault.thuillier@epitech.eu', 'thomas.darrieumerlou@epitech.eu', 'thomas.gireaudot@epitech.eu', 'thomas.koebel@epitech.eu', 'thomas.rabiet@epitech.eu', 'thomas.weinstein@epitech.eu', 'thomas.willson@epitech.eu', 'tibo.pendino@epitech.eu', 'tom.boulanger@epitech.eu', 'tom.laumonier@epitech.eu', 'toni.da-r ...
# Extracting data for G9 - Free Projects (G-INN-920)
# Appointements: []
# Activities: []
# Project: None
# Registered: ['mateo.baldassi@epitech.eu', 'valentin.cureau@epitech.eu']
# Extracting data for G9 - Hackathon (G-INN-910)
# Appointements: []
# Activities: []
# Project: None
# Registered: ['antonin.duthil@epitech.eu', 'irvan.assiakoley@epitech.eu', 'mateo.baldassi@epitech.eu', 'seraphin.perrot@epitech.eu', 'valentin.cureau@epitech.eu']
# Extracting data for G9 - Talks & Conferences (G-INN-901)
# Appointements: []
# Activities: []
# Project: None
# Registered: ['alex-anderson.mysengsay@epitech.eu', 'mateo.baldassi@epitech.eu', 'valentin.cureau@epitech.eu']
# Extracting data for G9 - User Groups (G-INN-930)
# Appointements: []
# Activities: []
# Project: None
# Registered: ['mateo.baldassi@epitech.eu', 'valentin.cureau@epitech.eu']
# Extracting data for M - Blockchain (M-BKC-900)
# Appointements: [{'name': 'Final Defense', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}]
# Activities: [{'name': 'Day 2', 'location': 'KB4 - Paritalie » 4eme - Dennis Ritchie (55 places)'}, {'name': 'Day 1', 'location': 'KB4 - Paritalie » 4eme - Dennis Ritchie (55 places)'}]
# Project: {'name': 'Project', 'link': 'https://intra.epitech.eu/module/2024/M-BKC-900/PAR-9-1/acti-646587/project/#!/group', 'start_date': '28/11/2024, 09h30', 'end_date': '10/01/2025, 23h59'}
# Registered: ['adam.mellakh@epitech.eu', 'alexandre.chevalier@epitech.eu', 'alexandre.schaffner@epitech.eu', 'amoz.pay@epitech.eu', 'antoine.gavira-bottari@epitech.eu', 'antoine1.paul@epitech.eu', 'antonin.duthil@epitech.eu', 'basile.lamotte@epitech.eu', 'bill.on@epitech.eu', 'david1.lin@epitech.eu', 'dominique.kambale-baraka@epitech.eu', 'eleonore.wichegrod@epitech.eu', 'famous.sounton@epitech.eu', 'hakim.redjem@epitech.eu', 'irvan.assiakoley@epitech.eu', 'jeremie.germond@epitech.eu', 'josue.houssou@epitech.eu', 'jude.marzat@epitech.eu', 'jules.bertrand@epitech.eu', 'killian.fleury@epitech.eu', 'lenny.vongphouthone@epitech.eu', 'louis.pavlovsky@epitech.eu', 'louis.piochaud@epitech.eu', 'loys.caucheteux@epitech.eu', 'lucas.mancini@epitech.eu', 'lucas.miranville@epitech.eu', 'marc.zhou@epitech.eu', 'marine.poteau@epitech.eu', 'matthieu.dubreuil@epitech.eu', 'nathan.duchesne@epitech.eu', 'nell.fauveau@epitech.eu', 'nicolas.saclier@epitech.eu', 'pierre-alexandre.delgado-arevalo@epitech.eu', 'quentin.marchand@epitech.eu', 'romain.leemans@epitech.eu', 'sandro.sgro@epitech.eu', 'tao.weijie@epitech.eu', 'theo.boryczewski@epitech.eu', 'thibaud.charrier@epitech.eu', 'tiago.martins-sousa@epitech.eu', 'tristan.gremont@epitech.eu', 'wassini.bouzidi@epitech.eu', 'xavier.tonnellier@epitech.eu']
# Extracting data for M - Boostez votre carrière ! (M-PRO-060)
# Appointements: []
# Activities: [{'name': 'Day 2', 'location': 'KB4 - Paritalie » 4eme -
 'location': 'N/A'}, {'name': 'Group C - S6 - Delivery - Lawal', 'location': 'N/A'}, {'name': 'Group C - S6 - Delivery - Jean-Philippe', 'location': 'N/A'}, {'name': 'Group C - S6 - Delivery - Victor', 'location': 'N/A'}, {'name': 'Group C - S6 - Delivery - Jean', 'location': 'N/A'}, {'name': 'Group C - S6 - Delivery - Faizal', 'location': 'N/A'}, {'name': 'Group C - S6 - Delivery - Lisa', 'location': '\n\t\t\t\t\tDelivery\t\t\t\t'}, {'name': 'Group C - S6 - Delivery - Marianne', 'location': 'N/A'}, {'name': 'Group B - S6 - Delivery - Flavien', 'location': 'N/A'}, {'name': 'Group B - S6 - Delivery - Victor', 'location': 'N/A'}, {'name': 'Group B - S6 - Delivery - Jean', 'location': 'N/A'}, {'name': 'Group B - S6 - Delivery - Faizal', 'location': 'N/A'}, {'name': 'Group B - S6 - Delivery - Lisa', 'location': '\n\t\t\t\t\tDelivery\t\t\t\t'}, {'name': 'Group B - S6 - Delivery - Lawal', 'location': 'N/A'}, {'name': 'Group B - S6 - Delivery - Marianne', 'location': 'N/A'}, {'name': 'Group A - S6 - Delivery - Jean', 'location': 'N/A'}, {'name': 'Group A - S6 - Delivery - Victor', 'location': 'N/A'}, {'name': 'Group A - S6 - Delivery - Faizal', 'location': '\n\t\t\t\t\tDelivery \t\t\t\t'}, {'name': 'Group A - S6 - Delivery - Lisa', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}, {'name': 'Group A - S6 - Delivery - Lawal', 'location': 'N/A'}, {'name': 'Group A - S6 - Delivery - Marianne', 'location': 'N/A'}, {'name': 'Group C - S6 - Follow-up - Jean-Philippe', 'location': 'N/A'}, {'name': 'Group C - S6 - Follow-up - Victor', 'location': 'N/A'}, {'name': 'Group C - S6 - Follow-up - Jean', 'location': 'N/A'}, {'name': 'Group C - S6 - Follow-up - Faizal', 'location': '\n\t\t\t\t\tFollow-Up\t\t\t\t'}, {'name': 'Group C - S6 - Follow-up - Lisa', 'location': '\n\t\t\t\t\tFollow-up\t\t\t\t'}, {'name': 'Group C - S6 - Follow-up - Lawal', 'location': 'N/A'}, {'name': 'Group C - S6 - Follow-up - Marianne', 'location': 'N/A'}, {'name': 'Coaching Pitch&Démo - Trophées des EIP - 1', 'location': 'N/A'}, {'name': 'Group B - S6 - Follow-up - Flavien', 'location': 'N/A'}, {'name': 'Group B - S6 - Follow-up - Victor', 'location': 'N/A'}, {'name': 'Group B - S6 - Follow-up - Jean', 'location': 'N/A'}, {'name': 'Group B - S6 - Follow-up - Lawal', 'location': 'N/A'}, {'name': 'Group B - S6 - Follow-up - Faizal', 'location': '\n\t\t\t\t\tFollow-Up\t\t\t\t'}, {'name': 'Group B - S6 - Follow-up - Lisa', 'location': '\n\t\t\t\t\tFollow-up\t\t\t\t'}, {'name': 'Group B - S6 - Follow-up - Marianne', 'location': 'N/A'}, {'name': 'Group A - S6 - Follo ...
# Activities: []
# Project: {'name': "Soutenance interne - Retour d'experience - Flavien", 'link': 'https://intra.epitech.eu/module/2024/M-EIP-900/PAR-9-1/acti-669520/project/#!/group', 'start_date': '30/01/2025, 00h00', 'end_date': '22/02/2025, 00h00'}
# Registered: ['abdelkarim.bengrine@epitech.eu', 'adam.mellakh@epitech.eu', 'adria.marata-fernandez@epitech.eu', 'adrien.bonvallet@epitech.eu', 'adrien.busnel@epitech.eu', 'adrien.fort@epitech.eu', 'adrien.moreau@epitech.eu', 'adrien.thibault@epitech.eu', 'adrien.zobiri@epitech.eu', 'ahmed.abouelleil-sayed@epitech.eu', 'alban.de-tourtier@epit
}]
# Activities: [{'name': 'Day 2', 'location': 'Batiment principal (disabled) » Visio (disabled) (25 places)'}, {'name': 'Day 1', 'location': 'Batiment principal (disabled) » Visio (disabled) (25 places)'}]
# Project: None
# Registered: ['adam.mellakh@epitech.eu', 'axel.fuentes@epitech.eu', 'clement.ozor@epitech.eu', 'emilien.buguet@epitech.eu', 'franck-valentino.folio@epitech.eu', 'guillaume.morin@epitech.eu', 'hildebert.jeanjean@epitech.eu', 'hugo.des-mares-de-trebons@epitech.eu', 'ismael.brossaud@epitech.eu', 'leena.saibi@epitech.eu', 'louis.riedlinger@epitech.eu', 'lucas.soury@epitech.eu', 'mathias.atchapa@epitech.eu', 'mohamed-aziz.cherif@epitech.eu', 'nathan.diaz@epitech.eu', 'nicolas.lavigne@epitech.eu', 'nicolas.moreau@epitech.eu', 'quentin.robert@epitech.eu', 'robin.landraud@epitech.eu', 'thibault.dufaure-de-citres@epitech.eu', 'thomy.lorenzatti@epitech.eu', 'valentin.eyraud@epitech.eu', 'victor.harri-chal@epitech.eu', 'william1.piloz@epitech.eu', 'yann.joubert@epitech.eu']
# Extracting data for M - Leadership innovant (M-MGT-905)
# Appointements: [{'name': 'Final grade', 'location': 'N/A'}]
# Activities: [{'name': 'Day 3', 'location': 'Batiment principal (disabled) » Visio (disabled) (25 places)'}, {'name': 'Day 2', 'location': 'Batiment principal (disabled) » Visio (disabled) (25 places)'}, {'name': 'Day 1', 'location': 'Batiment principal (disabled) » Visio (disabled) (25 places)'}]
# Project: None
# Registered: ['damien.juan@epitech.eu', 'franck-valentino.folio@epitech.eu', 'gabrielle.walgraef@epitech.eu', 'geoffroy-.stanger-@epitech.eu', 'guillaume.morin@epitech.eu', 'jonathan.albac@epitech.eu', 'leena.saibi@epitech.eu', 'lenny.francois-marie@epitech.eu', 'lucas.bertrand@epitech.eu', 'mathias.atchapa@epitech.eu', 'mathieu.muty@epitech.eu', 'mathis.lechopier@epitech.eu', 'matis.levrault@epitech.eu', 'mattis.dalleau@epitech.eu', 'mohamed-aziz.cherif@epitech.eu', 'nassim.alaimi@epitech.eu', 'nicolas.lavigne@epitech.eu', 'nicolas.salimina@epitech.eu', 'robin.landraud@epitech.eu', 'rodolphe.dedant@epitech.eu', 'team.bodzen@epitech.eu', 'thomas.darrieumerlou@epitech.eu', 'thomy.lorenzatti@epitech.eu', 'tristan.beau@epitech.eu', 'valentin.eyraud@epitech.eu']
# Extracting data for M - Les clés du cadrage de projet niveau I (M-PRO-902)
# Appointements: [{'name': 'Final defense', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}]
# Activities: [{'name': 'Day 2', 'location': 'KB4 - Paritalie » 4ème - Margaret Hamilton (48 places)'}, {'name': 'Day 1', 'location': 'KB4 - Paritalie » 4ème - Margaret Hamilton (35 places)'}]
# Project: {'name': 'Project', 'link': 'https://intra.epitech.eu/module/2024/M-PRO-902/PAR-9-1/acti-646289/project/#!/group', 'start_date': '19/09/2024, 09h30', 'end_date': '18/10/2024, 23h59'}
# Registered: ['alain1.nguyen@epitech.eu', 'amoz.pay@epitech.eu', 'audrey.amar@epitech.eu', 'baptiste.barbotin@epitech.eu', 'baptiste.mounier-vanderhaegen-gillot@epitech.eu', 'charly.le-corre@epitech.eu', 'come.benezet@epitech.eu', 'corentin.langlois@epitech.eu', 'irvan.assiakoley@epitech.eu', 'nicolas.saclier@epitech.eu', 'paul.rosenkranz@epitech.eu', 'quentin.capelle@epitech.eu']
# Extracting data for M - Les clés du cadrage projet niveau II  (M-PRO-904)
# Appointements: [{'name': 'Final defense', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}]
# Activities: [{'name': 'Day 2', 'location': 'Batiment principal (disabled) » Visio (disabled) (35 places)'}, {'name': 'Day 1', 'location': 'Batiment principal (disabled) » Visio (disabled) (35 places)'}]
# Project: {'name': 'Project', 'link': 'https://intra.epitech.eu/module/2024/M
# Extracting data for M - Reverse Engineering & Cracking I (M-SEC-901)
# Appointements: [{'name': 'Final Defense', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}]
# Activities: [{'name': 'Day 2', 'location': 'KB4 - Paritalie » 4ème - Galilée (55 places)'}, {'name': 'Day 1', 'location': 'KB4 - Paritalie » 4ème - Galilée (55 places)'}]
# Project: {'name': 'Project', 'link': 'https://intra.epitech.eu/module/2024/M-SEC-901/PAR-9-2/acti-646693/project/#!/group', 'start_date': '14/11/2024, 09h30', 'end_date': '13/12/2024, 23h59'}
# Registered: ['adrien.moreau@epitech.eu', 'antoine.gavira-bottari@epitech.eu', 'antoine1.paul@epitech.eu', 'antonin.duthil@epitech.eu', 'arent.dollapaj@epitech.eu', 'arthur.delbarre@epitech.eu', 'axel.medan@epitech.eu', 'benjamin.fenasse@epitech.eu', 'david.gozlan@epitech.eu', 'erwan.baillon@epitech.eu', 'graham.de-santana@epitech.eu', 'guilhem.sante@epitech.eu', 'hugo.duval@epitech.eu', 'hugo.kirch@epitech.eu', 'irvan.assiakoley@epitech.eu', 'lenny.vongphouthone@epitech.eu', 'lucie.thomas@epitech.eu', 'ludovic.peltier@epitech.eu', 'marvin.verain@epitech.eu', 'maxime.verrier@epitech.eu', 'maylis.ducournau@epitech.eu', 'melinda.saglam@epitech.eu', 'nataniel-.louis@epitech.eu', 'nathan.casabieille@epitech.eu', 'nino.ben-kemoun@epitech.eu', 'quentin.leroueil@epitech.eu', 'rayane.eloudjedi@epitech.eu', 'tanguy.viriot@epitech.eu', 'thomas.prudhomme@epitech.eu', 'victor.vindevogel@epitech.eu', 'yaacov.levy@epitech.eu', 'yoann.chelin@epitech.eu']
# Extracting data for M - Securite offensive et exploitation (M-SEC-905)
# Appointements: [{'name': 'Follow-up', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}, {'name': 'Final Defense', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}]
# Activities: [{'name': 'Day 2', 'location': 'KB4 - Paritalie » 4eme - Dennis Ritchie (55 places)'}, {'name': 'Day 1', 'location': 'KB4 - Paritalie » 4eme - Dennis Ritchie (55 places)'}]
# Project: {'name': 'Project', 'link': 'https://intra.epitech.eu/module/2024/M-SEC-905/PAR-9-2/acti-646704/project/#!/group', 'start_date': '30/01/2025, 09h30', 'end_date': '07/03/2025, 23h59'}
# Registered: ['Aucun étudiant']
# Extracting data for M - Strategie d'entreprise (M-TRV-001)
# Appointements: [{'name': 'Final defense', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}]
# Activities: [{'name': 'Day 2', 'location': 'Batiment principal (disabled) » Visio (disabled) (55 places)'}, {'name': 'Day 1', 'location': 'Batiment principal (disabled) » Visio (disabled) (55 places)'}]
# Project: {'name': 'Project', 'link': 'https://intra.epitech.eu/module/2024/M-TRV-001/PAR-9-2/acti-646341/project/#!/group', 'start_date': '10/10/2024, 09h30', 'end_date': '08/11/2024, 23h59'}
# Registered: ['adam.mellakh@epitech.eu', 'alex1.prevot@epitech.eu', 'arthur.duhot@epitech.eu', 'baptiste.kelagopian@epitech.eu', 'clement1.dubois@epitech.eu', 'come.benezet@epitech.eu', 'daniel.tirrier@epitech.eu', 'enguerrand.van-de-velde@epitech.eu', 'fabien.giraudier@epitech.eu', 'fernando.tabernero-pena@epitech.eu', 'graham.de-santana@epitech.eu', 'harry.pofagi@epitech.eu', 'ismael.brossaud@epitech.eu', 'llosa.romain@epitech.eu', 'loic.ye@epitech.eu', 'lorenzo.fortini@epitech.eu', 'louis.leblond@epitech.eu', 'mahe.faure@epitech.eu', 'marcel-auguste.denise@epitech.eu', 'marvin.flamand@epitech.eu', 'matheo.grail@epitech.eu', 'matheo.robert@epitech.eu', 'maxence.le-gars@epitech.eu', 'melinda.saglam@epitech.eu', 'michel-cliff.ogoudedji@epitech.eu', 'miguel.arnalot-borao@epitech.eu', 'nathan.zerbib@epitech.eu', 'nawelle.polin@epitech.eu', 'nicolas.julie@epitech.eu', 'n
 23h59'}
# Registered: ['adam.mellakh@epitech.eu', 'adrien.busnel@epitech.eu', 'amoz.pay@epitech.eu', 'anthony.becarne@epitech.eu', 'antoine.descamps@epitech.eu', 'antonin.duthil@epitech.eu', 'axel.boqueho@epitech.eu', 'benjamin.messmer@epitech.eu', 'bilel.barkallah@epitech.eu', 'charly.le-corre@epitech.eu', 'claire.cival@epitech.eu', 'emile.corvini@epitech.eu', 'erwan.baillon@epitech.eu', 'erwan.simonetti@epitech.eu', 'ewen.le-quere@epitech.eu', 'gregoire.biendine@epitech.eu', 'guilhem.sante@epitech.eu', 'harry.pofagi@epitech.eu', 'hugo.duval@epitech.eu', 'irvan.assiakoley@epitech.eu', 'julien.deviller@epitech.eu', 'juliette.destang@epitech.eu', 'keryan.oulier@epitech.eu', 'laurent.cazette@epitech.eu', 'leny.wilhelm@epitech.eu', 'loic.planchon@epitech.eu', 'louis.watrelos@epitech.eu', 'louison.kalifa@epitech.eu', 'lucas.mancini@epitech.eu', 'lucas.miranville@epitech.eu', 'mateo.baldassi@epitech.eu', 'maylis.ducournau@epitech.eu', 'nataniel-.louis@epitech.eu', 'nicolas.saclier@epitech.eu', 'nino.ben-kemoun@epitech.eu', 'paul.bachelet@epitech.eu', 'quentin.leroueil@epitech.eu', 'quentin.vandersteene@epitech.eu', 'seraphin.perrot@epitech.eu', 'simon.auduberteau@epitech.eu', 'soheil.khalil@epitech.eu', 'tanguy.viriot@epitech.eu', 'teo.gicquel@epitech.eu', 'theo.garnier@epitech.eu', 'thibaud.charrier@epitech.eu', 'thomas.giaroli@epitech.eu', 'timothee.de-boynes@epitech.eu', 'tomas.proust@epitech.eu', 'vincent.zhong@epitech.eu', 'yoann.chelin@epitech.eu']
# Extracting data for M - Venez construire votre projet de start-up (M-PRO-900)
# Appointements: [{'name': 'Final defense', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}]
# Activities: [{'name': 'Day 1', 'location': 'Batiment principal (disabled) » Visio (disabled) (30 places)'}, {'name': 'Day 2', 'location': 'Batiment principal (disabled) » Visio (disabled) (30 places)'}]
# Project: {'name': 'Project', 'link': 'https://intra.epitech.eu/module/2024/M-PRO-900/PAR-9-2/acti-646331/project/#!/group', 'start_date': '20/02/2025, 09h30', 'end_date': '28/03/2025, 23h59'}
# Registered: ['adam.mellakh@epitech.eu', 'bachir.benzaoui@epitech.eu', 'daniel.tirrier@epitech.eu', 'emilien.buguet@epitech.eu', 'franck-valentino.folio@epitech.eu', 'guillaume.morin@epitech.eu', 'hugo.duval@epitech.eu', 'hugo.touzeau@epitech.eu', 'julien.deviller@epitech.eu', 'kevin.gouyet@epitech.eu', 'leena.saibi@epitech.eu', 'leny.wilhelm@epitech.eu', 'lukas.chiaradia@epitech.eu', 'marvin.flamand@epitech.eu', 'matheo.robert@epitech.eu', 'mathis.laurent@epitech.eu', 'morgan.ehni@epitech.eu', 'nassim.alaimi@epitech.eu', 'nataniel-.louis@epitech.eu', 'nawelle.polin@epitech.eu', 'nicolas.chastin@epitech.eu', 'nino.ben-kemoun@epitech.eu', 'remi.huguet@epitech.eu', 'sandro.sgro@epitech.eu', 'thomas.darrieumerlou@epitech.eu', 'valentin.fouillet@epitech.eu', 'victoire.rabeau@epitech.eu', 'vitor-hugo.moreira-reis@epitech.eu', 'yanis.labchiri@epitech.eu', 'yann.joubert@epitech.eu']
# Extracting data for M - Web Security (M-SEC-902)
# Appointements: [{'name': 'Final Defense', 'location': 'Batiment principal (disabled) » Visio (disabled) (100 places)'}]
# Activities: [{'name': 'Day 2', 'location': 'KB4 - Paritalie » 4eme - Dennis Ritchie (55 places)'}, {'name': 'Day 1', 'location': 'KB4 - Paritalie » 4eme - Dennis Ritchie (55 places)'}]
# Project: {'name': 'Project', 'link': 'https://intra.epitech.eu/module/2024/M-SEC-902/PAR-9-2/acti-646697/project/#!/group', 'start_date': '16/01/2025, 09h30', 'end_date': '14/02/2025, 23h59'}
# Registered: ['alban.de-tourtier@epitech.eu', 'alex-anderson.mysengsay@epitech.eu', 'alexandre.schaffner@epitech.eu', 'alwyn.mattapullut@epitech.eu', 'anthony.vienne@epitech.eu', 'antoine.gavira-bottari@epitech.eu', 'arent.dollapaj@epitech.eu', 'arthur.delbarre@epitech.eu', 'axel.zenine@epitech.eu', 'basile.lamotte@epitech.eu', 'benjamin.fenasse@epitech.eu', 'bill.on@epitech.eu', 'caillat.romain@epitech.eu', 'clement.mikula@epitech.eu', 'dominique.kambale-baraka@epitech.eu', 'emile.corvini@epitech.eu', 'emin.atabey@epitech.eu', 'hugo.baret@epitech.eu', 'hugo.kirch@epitech.eu', 'jenny.zhu@epitech.eu', 'jonathan.albac@epitech.eu', 'josue.houssou@epitech.eu', 'julien.deviller@epitech.eu', 'juliette.destang@epitech.eu', 'laurent.hsia@epitech.eu', 'lenny.vongphouthone@epitech.eu', 'lilian.giroire@epitech.eu', 'louis.obeniche-rousse@epitech.eu', 'lucas.marteau@epitech.eu', 'matthieu.daumas@epitech.eu', 'max.cekanowski@epitech.eu', 'maxime.verrier@epitech.eu', 'mohamed-reda.ramdani@epitech.eu', 'mohamed.ghalab@epitech.eu', 'nataniel-.louis@epitech.eu', 'nell.fauveau@epitech.eu', 'nicolas.julie@epitech.eu', 'nicolas.reboule@epitech.eu', 'nino.ben-kemoun@epitech.eu', 'pierrick.cheviron@epitech.eu', 'quentin.robert@epitech.eu', 'rodrigue.bouschet@epitech.eu', 'royale.badiabo@epitech.eu', 'tanguy.viriot@epitech.eu', 'theo.boryczewski@epitech.eu', 'theo.garnier@epitech.eu', 'thomas.giaroli@epitech.eu', 'timothee.de-boynes@epitech.eu', 'todor.zugic@epitech.eu', 'tristan.gremont@epitech.eu', 'valentin.cureau@epitech.eu', 'yacine.abu-khalil@epitech.eu', 'yann-arthur.tcheumani@epitech.eu', 'younes1.bahri@epitech.eu']

# %% [markdown]
# ## Save the data to a csv that we will use in the frontend

# %%
def write_csv(modules):
    with open('modules.csv', 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["module_title", "module_url", "module_code", "module_instance", "module_credits", "module_skills", "module_start_date", "module_end_date", "module_end_registration_date", "on_site", "project_name", "project_link", "project_start_date", "project_end_date", "module_activities", "module_appointements", "module_locations", "module_registered"])
        for module in modules:
            writer.writerow([module.title, module.get_url(), module.code, module.instance, module.credits, ','.join(module.skills), module.startDate, module.endDate, module.endRegistrationDate, module.isPresential, module.project_name, module.project_link, module.project_start_date, module.project_end_date, ','.join(module.activities),  ','.join(module.appointements), ','.join(module.locations), ','.join(module.registered)])
write_csv(modules)
